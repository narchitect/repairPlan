# %%
from utils.loader import load_scene_graph
from data.robots import robots_withConfig
from planner.planner_initialPlanner_o1_wo_question import identify_defect_node, select_robot
       
user_description = "the wall has a crack and it is located toward north in the room 9"
scene_graph = load_scene_graph("/Users/nayunkim/Documents/GitHub/repairPlan/data/sceneGraphs/new_structure/3dsg_full.json")
robot_DB = robots_withConfig

# %%
defect_id = identify_defect_node(user_description, scene_graph)
# Out:
# To address the user's input about a crack on a wall located to the north in room 9, let's analyze the information provided in the 3D scene graph:
#
# 1. **Room Identification:**
#    According to the input, the defect is in room with ID 9.
#
# 2. **Wall Identification:**
#    Room 9 has walls with the following IDs: 1004, 1103, 3025, 1131, 2059, 1197.
#    Since the defect is described as a crack on the wall at the "north" side of the room, we need to determine which wall aligns with the northerly direction in the given coordinates.
#
#    Room locations are given in the form of [x, y, z]. A northerly wall in 3D space typically involves the wall with consistent or changing y-coordinates in relation to other walls which bounds the space in a way that would make sense narratively based on common spatial logic (where at top of map is considered north). The wall with the greatest y-coordinate within this room can be viewed as the northernmost wall.
#
# ...

# %%
robot_id = select_robot(user_description, defect_id, robot_DB)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 robot_id = select_robot(user_description, defect_id, robot_DB)
#
# File ~/Documents/GitHub/repairPlan/planner/planner_initialPlanner_o1_wo_question.py:66, in select_robot(user_input, defect_id, robot_db, gpt_model)
#      46 defect_info = get_node_info(defect_id)
#      48 prompt = f"""
#      49 You are an expert in robot capabilities and reachability.
#      50
#    (...)
#      63 }}
#      64 """
# ---> 66 response = client.chat.completions.create(
#      67     model="o1-preview",
#      68     messages=[
#      69         {
#      70             "role": "user",
#      71             "content": prompt
#      72         }
#      73     ],
#      74 )
#      76 output = response.choices[0].message.content
#      77 print(output)
#
# ...

# %%
from utils.loader import get_node_info

print(type(defect_id))
print(get_node_info(defect_id))
# Out:
# <class 'int'>
# {'error': 'Node 1004 not found'}
