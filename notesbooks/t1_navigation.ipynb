# %%
from utils.loader import load_scene_graph
from data.robots import robots_withConfig
from planner.planner_navigation_o1 import get_navigationPath_o1
from planner.planner_navigation import get_navigationPath
from utils.loader import get_node_info
from visualizer.vis_navigation import visualize_navigation


user_description = "there is a crak on a wall in the room id 9"
scene_graph = load_scene_graph("/Users/nayunkim/Documents/GitHub/repairPlan/data/sceneGraphs/new_structure/3dsg_full.json")
robot_DB = robots_withConfig
defect_id = 1004

# %%
print(get_node_info(1004))

# %%
get_navigationPath_o1(defect_id, scene_graph)

# %%
path = [41, 5068, 5, 5062, 6, 5000, 9]
visualize_navigation(path, defect_id, scene_graph, "/Users/nayunkim/Documents/GitHub/repairPlan/data/images/top_view.png", "/Users/nayunkim/Documents/GitHub/repairPlan/data/images/t1_navigation_output.png")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 2
#       1 path = [41, 5068, 5, 5062, 6, 5000, 9]
# ----> 2 visualize_navigation(path, defect_id, scene_graph, "/Users/nayunkim/Documents/GitHub/repairPlan/data/images/top_view.png", "/Users/nayunkim/Documents/GitHub/repairPlan/data/images/t1_navigation_output.png")
#
# File ~/Documents/GitHub/repairPlan/visualizer/vis_navigation.py:72, in visualize_navigation(path, defect_id, data, image_path, output_path)
#      69 ax.axis("equal")
#      71 # 노드 색상 설정
# ---> 72 node_colors = [
#      73     'blue' if node_types[node] == 'Space' else
#      74     'green' if node_types[node] == 'Door' else
#      75     'red' if node_types[node] == 'Window' else
#      76     'orange' if node_types[node] == 'Defect' else 'gray' for node in H.nodes  # 결함 노드는 주황색으로 설정
#      77 ]
#      79 # 경로에 포함된 그래프를 이미지 위에 오버레이
#      80 nx.draw(
#      81     H,
#      82     pos,
#    (...)
#      92     arrowstyle='->',
#      93 )
#
# File ~/Documents/GitHub/repairPlan/visualizer/vis_navigation.py:73, in <listcomp>(.0)
#      69 ax.axis("equal")
#      71 # 노드 색상 설정
#      72 node_colors = [
# ---> 73     'blue' if node_types[node] == 'Space' else
#      74     'green' if node_types[node] == 'Door' else
#      75     'red' if node_types[node] == 'Window' else
#      76     'orange' if node_types[node] == 'Defect' else 'gray' for node in H.nodes  # 결함 노드는 주황색으로 설정
#      77 ]
#      79 # 경로에 포함된 그래프를 이미지 위에 오버레이
#      80 nx.draw(
#      81     H,
#      82     pos,
#    (...)
#      92     arrowstyle='->',
#      93 )
#
# KeyError: 5068

# %%
get_navigationPath(defect_id,scene_graph)
