# %%
from utils.loader import load_scene_graph
from data.robots import robots_withConfig
from planner.planner_navigation_o1 import get_navigationPath_o1
from planner.planner_navigation import get_navigationPath
from utils.loader import get_node_info
from planner.planner_a_start import a_star_path_planner
from visualizer.vis_navigation import visualize_navigation


user_description = "there is a crak on a wall in the room id 9"
scene_graph = load_scene_graph("/Users/nayunkim/Documents/GitHub/repairPlan/data/sceneGraphs/new_structure/3dsg_full.json")
robot_DB = robots_withConfig
start_room = 46
target_room = 9
robot_id = 1

print(type(scene_graph))
print(scene_graph["links"])
# Out:
# <class 'dict'>
# ...

# %%
path = get_navigationPath_o1(target_room, scene_graph)
path_a_star = a_star_path_planner(scene_graph, start_room, target_room)
print(path_a_star)

visualize_navigation(path, 1004, scene_graph, "/Users/nayunkim/Documents/GitHub/repairPlan/data/images/top_view.png", "/Users/nayunkim/Documents/GitHub/repairPlan/data/images/t1_navigation_output.png")
# Out:
# To solve this task, I'll interpret the room connections as a graph where each room is a node and each connection between rooms is an edge with a door ID. The task is essentially finding the shortest path in terms of the number of doors to pass through from the robot's storage location to the defect location.
#
# Given:
# - Defect location (destination): Room 9
# - Robot's storage location (start): Room 46
#
# First, let's establish the connections based on the provided room configuration:
#
# 1. Room 46 connects to Room 59 via Door 5042.
#
# Now, we need to assess if there is a path from Room 59 to Room 9. Here’s the path analysis based on the provided connections:
#
# 1. From Room 46, move to Room 59 via Door 5042.
# 2. From Room 59, move to Room 44 via Door 5043.
# 3. From Room 44, move to Room 41 via Door 5054.
# 4. From Room 41, move to Room 24 via Door 5014.
# 5. From Room 24, move to Room 27 via Door 5026.
# 6. From Room 27, move to Room 26 via Door 5058.
# ...

# %%
[46, 5042, 59, 5043, 44, 5054, 41, 5014, 24, 5026, 27, 5058, 26, 5064, 44, 5054, 41, 5068, 5, 5062, 6, 5000, 9]
[46, 5042, 59, 5043, 44, 5054, 41, 5068, 5, 5062, 6, 5000, 9]
# Out:
# [46,
#  5042,
#  59,
#  5043,
#  44,
#  5054,
#  41,
#  5014,
#  24,
#  5026,
#  27,
#  5058,
#  26,
#  5064,
#  44,
#  5054,
#  41,
#  5068,
#  5,
#  5062,
#  6,
#  5000,
#  9]

# %%
path = [41, 5068, 5, 5062, 6, 5000, 9]
visualize_navigation(path, defect_id, scene_graph, "/Users/nayunkim/Documents/GitHub/repairPlan/data/images/top_view.png", "/Users/nayunkim/Documents/GitHub/repairPlan/data/images/t1_navigation_output.png")

# %%
path = get_navigationPath_o1(target_room, scene_graph)
path_a_star = a_star_path_planner(scene_graph, start_room, target_room)
print(path_a_star)

visualize_navigation(path, 1004, scene_graph, "/Users/nayunkim/Documents/GitHub/repairPlan/data/images/top_view.png", "/Users/nayunkim/Documents/GitHub/repairPlan/data/images/t1_navigation_output.png")
# Out:
# To solve this task, I'll interpret the room connections as a graph where each room is a node and each connection between rooms is an edge with a door ID. The task is essentially finding the shortest path in terms of the number of doors to pass through from the robot's storage location to the defect location.
#
# Given:
# - Defect location (destination): Room 9
# - Robot's storage location (start): Room 46
#
# First, let's establish the connections based on the provided room configuration:
#
# 1. Room 46 connects to Room 59 via Door 5042.
#
# Now, we need to assess if there is a path from Room 59 to Room 9. Here’s the path analysis based on the provided connections:
#
# 1. From Room 46, move to Room 59 via Door 5042.
# 2. From Room 59, move to Room 44 via Door 5043.
# 3. From Room 44, move to Room 41 via Door 5054.
# 4. From Room 41, move to Room 24 via Door 5014.
# 5. From Room 24, move to Room 27 via Door 5026.
# 6. From Room 27, move to Room 26 via Door 5058.
# ...

# %%
get_navigationPath(defect_id,scene_graph)
