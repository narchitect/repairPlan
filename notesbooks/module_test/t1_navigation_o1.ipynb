# %%
from utils.loader import load_scene_graph
from data.robots import robots_withConfig
from planner.planner_navigation_o1 import get_navigationPath_o1
from planner.planner_navigation import get_navigationPath
from utils.loader import get_node_info, get_rooms_info
from visualizer.vis_navigation import visualize_navigation


user_description = "there is a crak on a wall in the room id 9"
scene_graph_full = load_scene_graph("/Users/nayunkim/Documents/GitHub/repairPlan/data/sceneGraphs/new_structure/3dsg_full.json")
scene_graph_trimmed = load_scene_graph("/Users/nayunkim/Documents/GitHub/repairPlan/data/sceneGraphs/new_structure/3dsg_trimmed.json")
scene_graph_links = scene_graph_trimmed["links"]
robot_DB = robots_withConfig
defect_id = 1004

# %%
path_full = get_navigationPath_o1(defect_id, scene_graph_full)
# Out:
# ```json
# {
#   "navigation_path": [46, 5042, 59, 5043, 44, 5054, 41, 5068, 5, 5062, 6, 5000, 9]
# }
# ```
# {'navigation_path': [46, 5042, 59, 5043, 44, 5054, 41, 5068, 5, 5062, 6, 5000, 9]}

# %%
visualize_navigation(path_full["navigation_path"], defect_id, scene_graph_full, "/Users/nayunkim/Documents/GitHub/repairPlan/data/images/top_view.png", "/Users/nayunkim/Documents/GitHub/repairPlan/data/images/t1_navigation_output.png")

# %%
path_trimmed = get_navigationPath_o1(defect_id, scene_graph_trimmed)
# Out:
# ```json
# {
#     "navigation_path": [46, 5042, 59, 5043, 44, 5054, 41, 5068, 5, 5062, 6, 5000, 9]
# }
# ```
# {'navigation_path': [46, 5042, 59, 5043, 44, 5054, 41, 5068, 5, 5062, 6, 5000, 9]}

# %%
visualize_navigation(path_trimmed["navigation_path"], defect_id, scene_graph_full, "/Users/nayunkim/Documents/GitHub/repairPlan/data/images/top_view.png", "/Users/nayunkim/Documents/GitHub/repairPlan/data/images/t1_navigation_output_trimmed.png")

# %%
path_links = get_navigationPath_o1(defect_id, scene_graph_links)
# Out:
# ```json
# {
#   "navigation_path": [46, 5042, 59, 5043, 44, 5054, 41, 5068, 5, 5062, 6, 5000, 9]
# }
# ```
# {'navigation_path': [46, 5042, 59, 5043, 44, 5054, 41, 5068, 5, 5062, 6, 5000, 9]}

# %%
print(path_links)
print(path_links["navigation_path"])
path_links_list = path_links["navigation_path"]
# Out:
# {'navigation_path': [46, 5042, 59, 5043, 44, 5054, 41, 5068, 5, 5062, 6, 5000, 9]}
# [46, 5042, 59, 5043, 44, 5054, 41, 5068, 5, 5062, 6, 5000, 9]

# %%
visualize_navigation(path_links_list, defect_id, scene_graph_full, "/Users/nayunkim/Documents/GitHub/repairPlan/data/images/top_view.png", "/Users/nayunkim/Documents/GitHub/repairPlan/data/images/t1_navigation_output_links.png")
