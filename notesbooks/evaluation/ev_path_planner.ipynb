# %%
from evaluation.path_evl import evaluate_path_planner

# %%
evaluate_path_planner(10, "gpt-4o")
# Out:
# llm path: [46, 5042, 59, 5043, 44, 5041, 43, 5054, 41, 5046, 37, 5059, 39, 5052, 40, 5066, 34, 5035, 35]
# a* path: [46, 5042, 59, 5043, 44, 5054, 41, 5068, 5, 5062, 6, 5066, 34, 5035, 35]
# Path is valid: False
# llm path: [46, 5042, 59, 5043, 44, 5054, 41, 5022, 23]
# a* path: [46, 5042, 59, 5043, 44, 5054, 41, 5022, 23]
# Path is valid: True
# llm path: [46, 5042, 59, 5040, 45, 5041, 44, 5039, 61, 5037, 49]
# a* path: [46, 5042, 59, 5043, 44, 5054, 41, 5068, 5, 5062, 6, 5066, 34, 5034, 33, 5033, 48, 5032, 49]
# Path is valid: False
# llm path: [46, 5042, 59, 5043, 44, 5054, 41, 5061, 42]
# a* path: [46, 5042, 59, 5043, 44, 5054, 41, 5061, 42]
# Path is valid: True
# llm path: No path exists between the robot's storage location (room 46) and the defect's location (room 10) with the given connections.
# a* path: [46, 5042, 59, 5043, 44, 5054, 41, 5068, 5, 5062, 6, 5057, 3, 5048, 52, 5050, 10]
# llm path: [46, 5042, 59, 5043, 44, 5041, 43, 5059, 41, 5054, 44, 5041, 43, 5049, 34]
# ...
