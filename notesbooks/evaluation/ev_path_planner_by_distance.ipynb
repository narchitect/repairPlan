# %%
from evaluation.path_evl import evaluate_path_planner

# %%
evaluate_path_planner(10, "gpt-4o")
# Out:
# llm path: [46, 5042, 59, 5040, 45]
# a* path: [46, 5042, 59, 5040, 45]
# Path is valid: True
# llm path: [46, 5042, 59, 5043, 44]
# a* path: [46, 5042, 59, 5043, 44]
# Path is valid: True
# llm path: [46, 5042, 59, 5043, 44, 5054, 41, 5064, 26, 5051, 60]
# a* path: [46, 5042, 59, 5043, 44, 5064, 26, 5051, 60]
# Path is valid: False
# llm path: [46, 5042, 59, 5043, 44, 5054, 41, 5061, 42]
# a* path: [46, 5042, 59, 5043, 44, 5054, 41, 5061, 42]
# Path is valid: True
# llm path: [46, 5042, 59, 5043, 44, 5054, 41, 5068, 5, 5047, 38]
# a* path: [46, 5042, 59, 5043, 44, 5054, 41, 5068, 5, 5047, 38]
# Path is valid: True
# llm path: [46, 5042, 59, 5043, 44, 5035, 34]
# a* path: [46, 5042, 59, 5043, 44, 5054, 41, 5068, 5, 5062, 6, 5066, 34]
# Path is valid: False
# llm path: [46, 5042, 59, 5043, 44, 5054, 41, 5036, 33]
# a* path: [46, 5042, 59, 5043, 44, 5054, 41, 5068, 5, 5062, 6, 5066, 34, 5034, 33]
# Path is valid: False
# llm path: [46, 5042, 59, 5043, 44, 5039, 41, 5054, 33, 5033, 48]
# ...

# %%
evaluate_path_planner(10, "o1-preview")
# Out:
# llm path: [46, 5042, 59, 5040, 45]
# a* path: [46, 5042, 59, 5040, 45]
# Path is valid: True
# llm path: [46, 5042, 59, 5043, 44]
# a* path: [46, 5042, 59, 5043, 44]
# Path is valid: True
# llm path: [46, 5042, 59, 5043, 44, 5064, 26, 5051, 60]
# a* path: [46, 5042, 59, 5043, 44, 5064, 26, 5051, 60]
# Path is valid: True
# llm path: [46, 5042, 59, 5043, 44, 5054, 41, 5061, 42]
# a* path: [46, 5042, 59, 5043, 44, 5054, 41, 5061, 42]
# Path is valid: True
# llm path: [46, 5042, 59, 5043, 44, 5054, 41, 5068, 5, 5047, 38]
# a* path: [46, 5042, 59, 5043, 44, 5054, 41, 5068, 5, 5047, 38]
# Path is valid: True
# llm path: [46, 5042, 59, 5043, 44, 5054, 41, 5068, 5, 5062, 6, 5066, 34]
# a* path: [46, 5042, 59, 5043, 44, 5054, 41, 5068, 5, 5062, 6, 5066, 34]
# Path is valid: True
# llm path: [46, 5042, 59, 5043, 44, 5054, 41, 5068, 5, 5062, 6, 5066, 34, 5034, 33]
# a* path: [46, 5042, 59, 5043, 44, 5054, 41, 5068, 5, 5062, 6, 5066, 34, 5034, 33]
# Path is valid: True
# ...

# %%
evaluate_path_planner(7, "gpt-4o",{ 
                        "distance1": 42, 
                        "distance2": 38,
                        "distance3": 34,
                        "distance4": 33,
                        "distance5": 48,
                        "distance6": 49,
                        "distance7": 32,
                    } )
# Out:
# trial: node distance1
# llm path: [46, 5042, 59, 5043, 44, 5054, 41, 5061, 42]
# a* path: [46, 5042, 59, 5043, 44, 5054, 41, 5061, 42]
# Path is valid: True
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 evaluate_path_planner(7, "gpt-4o",{
#       2                         "distance1": 42,
#       3                         "distance2": 38,
#       4                         "distance3": 34,
#       5                         "distance4": 33,
#       6                         "distance5": 48,
#       7                         "distance6": 49,
#       8                         "distance7": 32,
#       9                     } )
#
# File ~/Documents/GitHub/repairPlan/evaluation/path_evl.py:121, in evaluate_path_planner(trial_number, gpt_model, target_rooms)
#     118 if path_a_star and isinstance(path_a_star, list):
# ...
