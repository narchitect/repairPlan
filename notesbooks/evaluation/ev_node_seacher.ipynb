# %%
from evaluation.node_search_evl import evaluate_identify_defect_node
from planner.planner_initialPlanner_o1_wo_question import identify_defect_node
from utils.loader import GLOBAL_SCENE_GRAPH

# %%
evaluate_identify_defect_node(gpt_model="gpt-4o")
# Out:
# === Evaluation using model gpt-4o ===
#
# Evaluating Simple Inputs:
#
# Test 1: The wall with ID 1116 has a crack.
# Predicted Defect ID: 1116, Predicted Room ID: 7
# Ground Truth Defect ID: 1116, Ground Truth Room ID: 7
# Result: Correct
#
# Test 2: The wall with window ID 4055 needs to be painted.
# Predicted Defect ID: 1042, Predicted Room ID: 32
# Ground Truth Defect ID: 1042, Ground Truth Room ID: 32
# Result: Correct
#
# Test 3: The ceiling in room ID 32 is damaged.
# Predicted Defect ID: 2032, Predicted Room ID: 32
# Ground Truth Defect ID: 2055, Ground Truth Room ID: 32
# Result: Incorrect
#
# Test 4: The object located at [-26.1239, -7.47, 1.85] has a crack.
# Predicted Defect ID: 1116, Predicted Room ID: 7
# Ground Truth Defect ID: 1116, Ground Truth Room ID: 7
# Result: Correct
#
# Test 5: The ceiling with the size [9.799, 23.86, 0.0] has a crack.
# Predicted Defect ID: 1028, Predicted Room ID: 40
# Ground Truth Defect ID: 2024, Ground Truth Room ID: 40
# ...

# %%
failure_gpt4o_trial_ids_simple = [3]
failure_gpt4o_trial_ids_complex = [8, 9, 10]
evaluate_identify_defect_node(gpt_model="gpt-4o", simple_trial_ids=failure_gpt4o_trial_ids_simple, complex_trial_ids=failure_gpt4o_trial_ids_complex)
# Out:
# === Evaluation using model gpt-4o ===
#
# Evaluating Simple Inputs:
#
# Test 3: The ceiling in room ID 32 is damaged.
# Predicted Defect ID: 2032, Predicted Room ID: 32
# Ground Truth Defect ID: 2055, Ground Truth Room ID: 32
# Result: Incorrect
#
# Simple Inputs Accuracy: 0.00%
#
# Evaluating Complex Inputs:
#
# Test 8: The most northern door in the largest room is jammed.
# Predicted Defect ID: [5057], Predicted Room ID: 41
# Ground Truth Defect ID: 5065, Ground Truth Room ID: 40
# Result: Incorrect
#
# Test 9: The wall with one window in the room directly to the right of the entrance to room ID 26 has a crack.
# Predicted Defect ID: 4029, Predicted Room ID: 26
# Ground Truth Defect ID: 1024, Ground Truth Room ID: 27
# Result: Incorrect
#
# Test 10: Among the rooms with at least one door and one window, the window in the smallest room needs to be cleaned.
# Predicted Defect ID: [4000, 4001, 4002], Predicted Room ID: 2
# Ground Truth Defect ID: 4029, Ground Truth Room ID: 54
# ...

# %%
failure_trial_ids_simple = [5, 7, 10]
failure_trial_ids_complex = [3, 4, 5, 7, 8, 10]
evaluate_identify_defect_node(gpt_model="o1-preview", simple_trial_ids=failure_trial_ids_simple, complex_trial_ids=failure_trial_ids_complex)
# Out:
# === Evaluation using model o1-preview ===
#
# Evaluating Simple Inputs:
#
# Test 5: The object with size [0.0, 3.36, 3.7] has a crack.
# Predicted Defect ID: 1052, Predicted Room ID: 16
# Ground Truth Defect ID: 1117, Ground Truth Room ID: 7
# Result: Incorrect
#
# Test 7: The wall with 8 doors in the room id 6 needs to be painted.
# Predicted Defect ID: 1211, Predicted Room ID: 6
# Ground Truth Defect ID: 1211, Ground Truth Room ID: 6
# Result: Correct
#
# Test 10: The doors in room id 8 need to be cleaned.
# Predicted Defect ID: [5001, 5049], Predicted Room ID: 8
# Ground Truth Defect ID: [5001, 5049], Ground Truth Room ID: 8
# Result: Correct
#
# Simple Inputs Accuracy: 20.00%
#
# Evaluating Complex Inputs:
#
# Test 3: The door in room ID 42 that connects to room ID 41 needs cleaning.
# Predicted Defect ID: 5061, Predicted Room ID: 42
# Ground Truth Defect ID: 5061, Ground Truth Room ID: 42
# Result: Correct
#
# Test 4: The wall that faces north in the room id 40 has mold.
# ...

# %%
failure2_trial_ids_simple = [5]
failure2_trial_ids_complex = [4]
evaluate_identify_defect_node(gpt_model="o1-preview", simple_trial_ids=failure2_trial_ids_simple, complex_trial_ids=failure2_trial_ids_complex)
# Out:
# === Evaluation using model o1-preview ===
#
# Evaluating Simple Inputs:
#
# Test 5: The ceiling with the size [9.799, 23.86, 0.0] has a crack.
# Predicted Defect ID: 2024, Predicted Room ID: 40
# Ground Truth Defect ID: 2024, Ground Truth Room ID: 40
# Result: Correct
#
# Simple Inputs Accuracy: 10.00%
#
# Evaluating Complex Inputs:
#
# Test 4: The wall located on the north side in room ID 40 has mold.
# Predicted Defect ID: 1157, Predicted Room ID: 40
# Ground Truth Defect ID: 1157, Ground Truth Room ID: 40
# Result: Correct
#
# Complex Inputs Accuracy: 10.00%
#
# === End of Evaluation Trial ===

# %%
failure3_trial_ids_simple = [3]
failure3_trial_ids_complex = [2, 6, 9]
evaluate_identify_defect_node(gpt_model="o1-preview", simple_trial_ids=failure3_trial_ids_simple, complex_trial_ids=failure3_trial_ids_complex)
# Out:
# === Evaluation using model o1-preview ===
#
# Evaluating Simple Inputs:
#
# Test 3: The ceiling in room ID 32 is damaged.
# Predicted Defect ID: 2055, Predicted Room ID: 32
# Ground Truth Defect ID: 2055, Ground Truth Room ID: 32
# Result: Correct
#
# Simple Inputs Accuracy: 10.00%
#
# Evaluating Complex Inputs:
#
# Test 2: The wall in room ID 18 closest to the boundary with room ID 19 has a crack.
# Predicted Defect ID: 1093, Predicted Room ID: 18
# Ground Truth Defect ID: 1093, Ground Truth Room ID: 18
# Result: Correct
#
# Test 6: There seems to be water dripping from above in room ID 7, which may indicate a crack.
# Predicted Defect ID: 2000, Predicted Room ID: 7
# Ground Truth Defect ID: 2000, Ground Truth Room ID: 7
# Result: Correct
#
# Test 9: The wall with one window in the room directly to the right of the entrance to room ID 26 has a crack.
# Predicted Defect ID: 1054, Predicted Room ID: 26
# Ground Truth Defect ID: 1024, Ground Truth Room ID: 27
# Result: Incorrect
#
# ...

# %%
#the third attempt to evaluate the node seacher with gpt-4o
failure_trial_ids_simple = [10]
failure_trial_ids_complex = [2,3, 4, 5, 7, 8, 10]
evaluate_identify_defect_node(gpt_model="gpt-4o", simple_trial_ids=failure_trial_ids_simple, complex_trial_ids=failure_trial_ids_complex)
# Out:
# === Evaluation using model gpt-4o ===
#
# Evaluating Simple Inputs:
#
# Test 10: The doors in room id 8 need to be cleaned.
# Predicted Defect ID: [1008, 1061], Predicted Room ID: 8
# Ground Truth Defect ID: [5001, 5049], Ground Truth Room ID: 8
# Result: Incorrect
#
# Simple Inputs Accuracy: 0.00%
#
# Evaluating Complex Inputs:
#
# Test 2: The wall in room ID 18 closest to the boundary with room ID 19 has a crack.
# Predicted Defect ID: 1093, Predicted Room ID: 18
# Ground Truth Defect ID: 1093, Ground Truth Room ID: 18
# Result: Correct
#
# Test 3: The door in room ID 42 that connects to room ID 41 needs cleaning.
# Predicted Defect ID: 5061, Predicted Room ID: 42
# Ground Truth Defect ID: 5061, Ground Truth Room ID: 42
# Result: Correct
#
# Test 4: The wall located on the north side in room ID 40 has mold.
# Predicted Defect ID: 1013, Predicted Room ID: 40
# Ground Truth Defect ID: 1157, Ground Truth Room ID: 40
# Result: Incorrect
#
# ...

# %%
#the third attempt to evaluate the node seacher with gpt-4o
failure_trial_ids_simple = [10]
failure_trial_ids_complex = [ 8, 10]
evaluate_identify_defect_node(gpt_model="gpt-4o", simple_trial_ids=failure_trial_ids_simple, complex_trial_ids=failure_trial_ids_complex)
# Out:
# === Evaluation using model gpt-4o ===
#
# Evaluating Simple Inputs:
#
# Test 10: The doors in room id 8 need to be cleaned.
# Predicted Defect ID: [5049], Predicted Room ID: 8
# Ground Truth Defect ID: [5001, 5049], Ground Truth Room ID: 8
# Result: Incorrect
#
# Simple Inputs Accuracy: 0.00%
#
# Evaluating Complex Inputs:
#
# Test 8: The most northern door in the largest room is jammed.
# Predicted Defect ID: 5001, Predicted Room ID: 41
# Ground Truth Defect ID: 5065, Ground Truth Room ID: 40
# Result: Incorrect
#
# Test 10: Among the rooms with at least one door and one window, the window in the smallest room needs to be cleaned.
# Predicted Defect ID: [4009], Predicted Room ID: 30
# Ground Truth Defect ID: 4029, Ground Truth Room ID: 54
# Result: Incorrect
#
# Complex Inputs Accuracy: 0.00%
#
# === End of Evaluation Trial ===

# %%
#the forth attempt to evaluate the node seacher with gpt-4o
failure_trial_ids_simple = [10]
failure_trial_ids_complex = [ 4, 5, 7, 8, 10]
evaluate_identify_defect_node(gpt_model="gpt-4o", simple_trial_ids=failure_trial_ids_simple, complex_trial_ids=failure_trial_ids_complex)
# Out:
# === Evaluation using model gpt-4o ===
#
# Evaluating Simple Inputs:
#
# Test 10: The doors in room id 8 need to be cleaned.
# Predicted Defect ID: [5049, 5001], Predicted Room ID: 8
# Ground Truth Defect ID: [5001, 5049], Ground Truth Room ID: 8
# Result: Incorrect
#
# Simple Inputs Accuracy: 0.00%
#
# Evaluating Complex Inputs:
#
# Test 4: The wall located on the north side in room ID 40 has mold.
# Predicted Defect ID: 1157, Predicted Room ID: 40
# Ground Truth Defect ID: 1157, Ground Truth Room ID: 40
# Result: Correct
#
# Test 5: The wall to the immediate left after entering through door ID 5059 in room ID 39 has graffiti.
# Predicted Defect ID: 1040, Predicted Room ID: 39
# Ground Truth Defect ID: 1118, Ground Truth Room ID: 39
# Result: Incorrect
#
# Test 7: It feels like cold air is coming from outside in the room id 42.
# Predicted Defect ID: [1193], Predicted Room ID: 42
# Ground Truth Defect ID: 4022, Ground Truth Room ID: 42
# Result: Incorrect
#
# ...

# %%
#the fifth attempt to evaluate the node seacher with gpt-4o
failure_trial_ids_simple = [10]
failure_trial_ids_complex = [ 5, 7, 8, 10]
evaluate_identify_defect_node(gpt_model="gpt-4o", simple_trial_ids=failure_trial_ids_simple, complex_trial_ids=failure_trial_ids_complex)
# Out:
# === Evaluation using model gpt-4o ===
#
# Evaluating Simple Inputs:
#
# Test 10: The doors in room id 8 need to be cleaned.
# Predicted Defect ID: [5001, 5049], Predicted Room ID: 8
# Ground Truth Defect ID: [5001, 5049], Ground Truth Room ID: 8
# Result: Correct
#
# Simple Inputs Accuracy: 10.00%
#
# Evaluating Complex Inputs:
#
# Test 5: The wall to the immediate left after entering through door ID 5059 in room ID 39 has graffiti.
# Predicted Defect ID: [1063, 1082], Predicted Room ID: 39
# Ground Truth Defect ID: 1118, Ground Truth Room ID: 39
# Result: Incorrect
#
# Test 7: It feels like cold air is coming from outside in the room id 42.
# Predicted Defect ID: 1193, Predicted Room ID: 42
# Ground Truth Defect ID: 4022, Ground Truth Room ID: 42
# Result: Incorrect
#
# Test 8: The most northern door in the largest room is jammed.
# Predicted Defect ID: 5007, Predicted Room ID: 41
# Ground Truth Defect ID: 5065, Ground Truth Room ID: 40
# Result: Incorrect
#
# ...
