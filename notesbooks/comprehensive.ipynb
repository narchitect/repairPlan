# %%
from planner.planner_final import get_repair_plan
from data.robots import robots
from utils.loader import load_scene_graph

user_description = "there is a stain on the ceiling in room id 320."

scene_graph = load_scene_graph("../data/sceneGraphs/3dsg_withCOR.json")

robot_location = "the robot is currently in room id 332"
robot_library = robots

camera_fov = 90

# %%
repairPlan = get_repair_plan(user_description, scene_graph, robot_library, robot_location, camera_fov)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 repairPlan = get_repair_plan(user_description, scene_graph, robot_library, robot_location, camera_fov)
#
# File ~/Documents/GitHub/repairPlan/planner/planner_final.py:12, in get_repair_plan(user_description, scene_graph, robot_library, robot_location, camera_fov)
#       9 final_plan = []
#      11 #step1: inspection plan
# ---> 12 inspection_plan_json = get_inspectionPlan(user_description, scene_graph, robot_library, robot_location)
#      13 print(inspection_plan_json)
#      14 final_plan.append(inspection_plan_json)
#
# File ~/Documents/GitHub/repairPlan/planner/planner_inspection.py:84, in get_inspectionPlan(user_input, scene_graph, robots, robot_location)
#      82 def get_inspectionPlan(user_input, scene_graph, robots, robot_location):
#      83     #stage1
# ...

# %%
print(repairPlan)
